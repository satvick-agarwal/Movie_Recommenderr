# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("../data/cleaned_movies.csv")

# %%
df.shape
# Out:
# (278756, 9)

# %%
df.head()
# Out:
#    id                             title  vote_average  \
# 0   3               Shadows in Paradise         7.300
# 1   5                        Four Rooms         5.876
# 2   6                    Judgment Night         6.500
# 3   8  Life in Loops (A Megacities RMX)         7.200
# 4  11                         Star Wars         8.204
#
#                                             overview  popularity  \
# 0  Nikander, a rubbish collector and would-be ent...      2.4839
# 1  It's Ted the Bellhop's first night on the job....      4.2181
# 2  Four young friends, while taking a shortcut en...      4.2730
# 3  Timo Novotny labels his new project an experim...      2.2585
# 4  Princess Leia is captured and held hostage by ...     14.7943
#
#                                genres                        spoken_languages  \
# 0              Comedy, Drama, Romance                 svenska, suomi, English
# 1                              Comedy                                 English
# 2             Action, Crime, Thriller                                 English
# 3                         Documentary  English, हिन्दी, 日本語, Pусский, Español
# 4  Adventure, Action, Science Fiction                                 English
#
#    imdb_rating                                      combined_text
# 0          7.4  nikander, a rubbish collector and would-be ent...
# 1          6.7  it's ted the bellhop's first night on the job....
# 2          6.6  four young friends, while taking a shortcut en...
# 3          8.1  timo novotny labels his new project an experim...
# 4          8.6  princess leia is captured and held hostage by ...

# %%
df["genres"] = df["genres"].fillna("")

# %%
df.isnull().sum()
# Out:
# id                  0
# title               0
# vote_average        0
# overview            0
# popularity          0
# genres              0
# spoken_languages    0
# imdb_rating         0
# combined_text       0
# dtype: int64

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("all-MiniLM-L6-v2")

# %%
df = df[
    (df["imdb_rating"] >= 5) &
    (df["spoken_languages"].str.contains("English|Hindi|हिन्दी|हिंदी", regex=True))
]

# %%
df = df.sort_values("popularity", ascending=False).head(30000)
df = df.reset_index(drop=True)

# %%
df.shape
# Out:
# (30000, 9)

# %%
embeddings = model.encode(
    df["combined_text"].tolist(),
    batch_size=32,
    show_progress_bar=True
)

embeddings.shape
# Out:
# Batches:   0%|          | 0/938 [00:00<?, ?it/s]
# (30000, 384)

# %%
from sklearn.metrics.pairwise import cosine_similarity

def recommend_movies(movie_title, df, embeddings, top_k=5):
    # find index of movie
    idx = df[df["title"].str.lower() == movie_title.lower()].index
    
    if len(idx) == 0:
        return "Movie not found"
    
    idx = idx[0]

    # compute similarity ONLY with one vector
    sim_scores = cosine_similarity(
        embeddings[idx].reshape(1, -1),
        embeddings
    )[0]

    # get top movies
    similar_indices = sim_scores.argsort()[-top_k-1:-1][::-1]

    return df.iloc[similar_indices][["title", "genres", "vote_average"]]

# %%
recommend_movies("Inception", df, similarity_matrix)
# Out:
#                                              title  \
# 5321                               Double Jeopardy
# 5512                                   American Me
# 3984                           Catch Us If You Can
# 6016  Billy Preston: That's the Way God Planned It
# 1722                              The Santa Clause
#
#                               genres  vote_average
# 5321        Drama, Thriller, Mystery         6.621
# 5512                    Crime, Drama         7.400
# 3984                   Comedy, Music         5.200
# 6016                     Documentary         0.000
# 1722  Fantasy, Drama, Comedy, Family         6.513

# %%
recommend_movies("Dangal", df, similarity_matrix)
# Out:
#                                       title                            genres  \
# 1698     Monty Python's The Meaning of Life                            Comedy
# 2921                       The Perfect Snob                   Romance, Comedy
# 2412                              Chronicle  Science Fiction, Drama, Thriller
# 800                          Audrie & Daisy                       Documentary
# 3016  Monsters In The Afternoon Programming
#
#       vote_average
# 1698         7.300
# 2921         6.300
# 2412         6.838
# 800          7.142
# 3016         0.000

# %%
np.save("../data/movie_embeddings.npy", embeddings)
df.to_csv("../data/cleaned_movies_30k.csv", index=False)
